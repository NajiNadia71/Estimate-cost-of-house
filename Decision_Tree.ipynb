# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline
df1 = pd.read_csv(r'C:/Users/ParsanAfzar/Documents/NoteJad/DataSet/Competition_Houses/Train.csv')
df1.head(15)
#SHow Unclean Data
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline
df = pd.read_csv(r'C:/Users/ParsanAfzar/Documents/NoteJad/MachineLearning_FinalProject/DataSet/TrainWithCode.csv')
df.head(15)
#Show Clean Data
# Out:
#     LotArea Neighborhood  OverallQual  YearBuilt Exterior1st ExterQual  \
# 0      8450      CollgCr            7       2003     VinylSd        Gd
# 1      9600      Veenker            6       1976     MetalSd        TA
# 2     11250      CollgCr            7       2001     VinylSd        Gd
# 3      9550      Crawfor            7       1915     Wd Sdng        TA
# 4     14260      NoRidge            8       2000     VinylSd        Gd
# 5     14115      Mitchel            5       1993     VinylSd        TA
# 6     10084      Somerst            8       2004     VinylSd        Gd
# 7     10382       NWAmes            7       1973     HdBoard        TA
# 8      6120      OldTown            7       1931     BrkFace        TA
# 9      7420      BrkSide            5       1939     MetalSd        TA
# 10    11200       Sawyer            5       1965     HdBoard        TA
# 11     7945        NAmes            5       1959     BrkFace        TA
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
# fit scaler on your training data
norm = MinMaxScaler().fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15904\2538972045.py in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 # fit scaler on your training data
# ----> 3 norm = MinMaxScaler().fit(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     414         # Reset internal state before fitting
#     415         self._reset()
# --> 416         return self.partial_fit(X, y)
#     417
#     418     def partial_fit(self, X, y=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     451
#     452         first_pass = not hasattr(self, "n_samples_seen_")
# --> 453         X = self._validate_data(
#     454             X,
#     455             reset=first_pass,
#
# ...
